# %%
from bs4 import BeautifulSoup
import requests
import csv
import json
import xml
import pandas as pd

# %%
column_names = ['Postalcode','Borough','Neighborhood']
toronto = pd.DataFrame(columns = column_names)

# %%
url='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
source = requests.get(url).text
soup = BeautifulSoup(source, 'lxml')#Beautiful Soup to Parse the url page
table=soup.find('table')
x=table.tbody

# %%
postcode = 0
borough = 0
neighborhood = 0

for tr in x.find_all('tr'):
    i = 0
    for td in tr.find_all('td'):
        if i == 0:
            postcode = td.text
            i = i + 1
        elif i == 1:
            borough = td.text
            i = i + 1
        elif i == 2:
            neighborhood = td.text.strip('\n').replace(']','')
    toronto = toronto.append({'Postalcode': postcode,'Borough': borough,'Neighborhood': neighborhood},ignore_index=True)

# %%
toronto = toronto[toronto.Borough!='Not assigned']
toronto = toronto[toronto.Borough!= 0]
toronto.reset_index(drop = True, inplace = True)
i = 0
for i in range(0,toronto.shape[0]):
    if toronto.iloc[i][2] == 'Not assigned':
        toronto.iloc[i][2] = toronto.iloc[i][1]
        i = i+1
                                 
df = toronto.groupby(['Postalcode','Borough'])['Neighborhood'].apply(', '.join).reset_index()
df.head()
# Out:
#   Postalcode      Borough                            Neighborhood
# 0        M1B  Scarborough                          Rouge, Malvern
# 1        M1C  Scarborough  Highland Creek, Rouge Hill, Port Union
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill
# 3        M1G  Scarborough                                  Woburn
# 4        M1H  Scarborough                               Cedarbrae

# %%
df = df.dropna()
empty = 'Not assigned'
df = df[(df.Postalcode != empty ) & (df.Borough != empty) & (df.Neighborhood != empty)]
df.head()
# Out:
#   Postalcode      Borough                            Neighborhood
# 0        M1B  Scarborough                          Rouge, Malvern
# 1        M1C  Scarborough  Highland Creek, Rouge Hill, Port Union
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill
# 3        M1G  Scarborough                                  Woburn
# 4        M1H  Scarborough                               Cedarbrae

# %%
def neighborhood_list(grouped):    
    return ', '.join(sorted(grouped['Neighborhood'].tolist()))
                    
grp = df.groupby(['Postalcode', 'Borough'])
df2 = grp.apply(neighborhood_list).reset_index(name='Neighborhood')
print(df2.shape)
df2.head()
# Out:
# (103, 3)
#   Postalcode      Borough                            Neighborhood
# 0        M1B  Scarborough                          Rouge, Malvern
# 1        M1C  Scarborough  Highland Creek, Rouge Hill, Port Union
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill
# 3        M1G  Scarborough                                  Woburn
# 4        M1H  Scarborough                               Cedarbrae

# %%
# !pip install geocoder
# Out:
# Collecting geocoder
#   Downloading https://files.pythonhosted.org/packages/4f/6b/13166c909ad2f2d76b929a4227c952630ebaf0d729f6317eb09cbceccbab/geocoder-1.38.1-py2.py3-none-any.whl (98kB)
#     100% |████████████████████████████████| 102kB 7.0MB/s ta 0:00:01
# Requirement not upgraded as not directly required: six in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from geocoder)
# Requirement not upgraded as not directly required: future in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from geocoder)
# Requirement not upgraded as not directly required: requests in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from geocoder)
# Requirement not upgraded as not directly required: click in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from geocoder)
# Collecting ratelim (from geocoder)
#   Downloading https://files.pythonhosted.org/packages/f2/98/7e6d147fd16a10a5f821db6e25f192265d6ecca3d82957a4fdd592cad49c/ratelim-0.1.6-py2.py3-none-any.whl
# Requirement not upgraded as not directly required: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from requests->geocoder)
# Requirement not upgraded as not directly required: idna<2.7,>=2.5 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from requests->geocoder)
# Requirement not upgraded as not directly required: urllib3<1.23,>=1.21.1 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from requests->geocoder)
# Requirement not upgraded as not directly required: certifi>=2017.4.17 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from requests->geocoder)
# Requirement not upgraded as not directly required: decorator in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from ratelim->geocoder)
# Installing collected packages: ratelim, geocoder
# Successfully installed geocoder-1.38.1 ratelim-0.1.6

# %%
import geocoder

# %%
def get_latlng(postal_code):
    # initialize your variable to None
    lat_lng_coords = None
    # loop until you get the coordinates
    while(lat_lng_coords is None):
        g = geocoder.arcgis('{}, Toronto, Ontario'.format(postal_code))
        lat_lng_coords = g.latlng
    return lat_lng_coords

# %%
get_latlng('M4G')
# Out:
# [43.70976500000006, -79.36379132299999]

# %%
postal_codes = df2['Postalcode']    
coords = [ get_latlng(postal_code) for postal_code in postal_codes.tolist() ]

# %%
df_coords = pd.DataFrame(coords, columns=['Latitude', 'Longitude'])
df['Latitude'] = df_coords['Latitude']
df['Longitude'] = df_coords['Longitude']

# %%
df[df.Postalcode == 'M5G']
# Out:
#    Postalcode           Borough        Neighborhood   Latitude  Longitude
# 57        M5G  Downtown Toronto  Central Bay Street  43.656091  -79.38493

# %%
df.head(10)
# Out:
#   Postalcode      Borough                                     Neighborhood  \
# 0        M1B  Scarborough                                   Rouge, Malvern
# 1        M1C  Scarborough           Highland Creek, Rouge Hill, Port Union
# 2        M1E  Scarborough                Guildwood, Morningside, West Hill
# 3        M1G  Scarborough                                           Woburn
# 4        M1H  Scarborough                                        Cedarbrae
# 5        M1J  Scarborough                              Scarborough Village
# 6        M1K  Scarborough      East Birchmount Park, Ionview, Kennedy Park
# 7        M1L  Scarborough                  Clairlea, Golden Mile, Oakridge
# 8        M1M  Scarborough  Cliffcrest, Cliffside, Scarborough Village West
# 9        M1N  Scarborough                      Birch Cliff, Cliffside West
#
#     Latitude  Longitude
# 0  43.811650 -79.195561
# 1  43.785605 -79.158701
# 2  43.765690 -79.175299
# 3  43.768216 -79.217610
# 4  43.769608 -79.239440
# 5  43.743085 -79.232172
# 6  43.726260 -79.263670
# 7  43.713213 -79.284910
# 8  43.723575 -79.234976
# 9  43.696690 -79.260069

# %%
# !pip install folium
# Out:
# Collecting folium
#   Downloading https://files.pythonhosted.org/packages/55/e2/7e523df8558b7f4b2ab4c62014fd378ccecce3fdc14c9928b272a88ae4cc/folium-0.7.0-py3-none-any.whl (85kB)
#     100% |████████████████████████████████| 92kB 7.2MB/s eta 0:00:01
# Collecting branca>=0.3.0 (from folium)
#   Downloading https://files.pythonhosted.org/packages/63/36/1c93318e9653f4e414a2e0c3b98fc898b4970e939afeedeee6075dd3b703/branca-0.3.1-py3-none-any.whl
# Requirement not upgraded as not directly required: jinja2 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from folium)
# Requirement not upgraded as not directly required: numpy in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from folium)
# Requirement not upgraded as not directly required: six in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from folium)
# Requirement not upgraded as not directly required: requests in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from folium)
# Requirement not upgraded as not directly required: MarkupSafe>=0.23 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from jinja2->folium)
# Requirement not upgraded as not directly required: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from requests->folium)
# Requirement not upgraded as not directly required: idna<2.7,>=2.5 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from requests->folium)
# Requirement not upgraded as not directly required: urllib3<1.23,>=1.21.1 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from requests->folium)
# Requirement not upgraded as not directly required: certifi>=2017.4.17 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from requests->folium)
# Installing collected packages: branca, folium
# Successfully installed branca-0.3.1 folium-0.7.0

# %%
import requests
from bs4 import BeautifulSoup as bs
import re

import numpy as np # library to handle data in a vectorized manner
import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

import folium # map rendering library

# %%
address = 'Toronto'

geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))

# create map of New York using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(df['Latitude'], df['Longitude'], df['Borough'], df['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7).add_to(map_toronto)  
#            parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# The geograpical coordinate of Toronto are 43.653963, -79.387207.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
scarborough_data = df[df['Borough'] == 'Scarborough'].reset_index(drop=True)
address1 = 'Scarborough,Toronto'

geolocator1 = Nominatim()
location1 = geolocator1.geocode(address1)
latitude1 = location1.latitude
longitude1 = location1.longitude
print('The geograpical coordinate of Scarborough are {}, {}.'.format(latitude1, longitude1))
# Out:
# The geograpical coordinate of Scarborough are 43.773077, -79.257774.

# %%
map_scarb = folium.Map(location=[latitude1, longitude1], zoom_start=11)

# add markers to map
for lat, lng, label in zip(scarborough_data['Latitude'], scarborough_data['Longitude'], scarborough_data['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7).add_to(map_scarb)  
#           parse_html=False).add_to(map_scarb)  
    
map_scarb
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# =============================================================================
# Import libraries
# =============================================================================
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
# =============================================================================
# 1. Download and Explore Dataset
# =============================================================================
# !wget -q -O 'newyork_data.json' https://ibm.box.com/shared/static/fbpwbovar7lf8p5sgddm06cgipa2rxpe.json
print('Data downloaded!')



#Load and explore the data
with open('newyork_data.json') as json_data:
    newyork_data = json.load(json_data)
newyork_data

neighborhoods_data = newyork_data['features']
neighborhoods_data[0]



#Tranform the data into a pandas dataframe
# define the dataframe columns
column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 

# instantiate the dataframe
neighborhoods = pd.DataFrame(columns=column_names)
neighborhoods



#Then let's loop through the data and fill the dataframe one row at a time.
for data in neighborhoods_data:
    borough = neighborhood_name = data['properties']['borough'] 
    neighborhood_name = data['properties']['name']
        
    neighborhood_latlon = data['geometry']['coordinates']
    neighborhood_lat = neighborhood_latlon[1]
    neighborhood_lon = neighborhood_latlon[0]
    
    neighborhoods = neighborhoods.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)
neighborhoods.head()
# Out:
# Data downloaded!
#   Borough Neighborhood   Latitude  Longitude
# 0   Bronx    Wakefield  40.894705 -73.847201
# 1   Bronx   Co-op City  40.874294 -73.829939
# 2   Bronx  Eastchester  40.887556 -73.827806
# 3   Bronx    Fieldston  40.895437 -73.905643
# 4   Bronx    Riverdale  40.890834 -73.912585

# %%
print('The dataframe has {} boroughs and {} neighborhoods.'.format(
        len(neighborhoods['Borough'].unique()),
        neighborhoods.shape[0]
    )
)
# Out:
# The dataframe has 5 boroughs and 306 neighborhoods.

# %%
#Use geopy library to get the latitude and longitude values of New York City
address = 'New York City, NY'
geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of New York City are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of New York City are 40.7308619, -73.9871558.

# %%
#Create a map of New York with neighborhoods superimposed on top
# create map of New York using latitude and longitude values
map_newyork = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(neighborhoods['Latitude'], neighborhoods['Longitude'], neighborhoods['Borough'], neighborhoods['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7).add_to(map_newyork)  
#        parse_html=False).add_to(map_newyork)  
    
map_newyork
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#However, for illustration purposes, let's simplify the above map and segment and cluster only the neighborhoods in Manhattan. So let's slice the original dataframe and create a new dataframe of the Manhattan data.
manhattan_data = neighborhoods[neighborhoods['Borough'] == 'Manhattan'].reset_index(drop=True)
manhattan_data.head()
# Out:
#      Borough        Neighborhood   Latitude  Longitude
# 0  Manhattan         Marble Hill  40.876551 -73.910660
# 1  Manhattan           Chinatown  40.715618 -73.994279
# 2  Manhattan  Washington Heights  40.851903 -73.936900
# 3  Manhattan              Inwood  40.867684 -73.921210
# 4  Manhattan    Hamilton Heights  40.823604 -73.949688

# %%
#Let's get the geographical coordinates of Manhattan.
address = 'Manhattan, NY'
geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Manhattan are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Manhattan are 40.7900869, -73.9598295.

# %%
#As we did with all of New York City, let's visualizat Manhattan the neighborhoods in it.
# create map of Manhattan using latitude and longitude values
map_manhattan = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(manhattan_data['Latitude'], manhattan_data['Longitude'], manhattan_data['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7).add_to(map_manhattan)  
#        parse_html=False).add_to(map_manhattan)  
    
map_manhattan
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Next, we are going to start utilizing the Foursquare API to explore the neighborhoods and segment them
#Define Foursquare Credentials and Version
CLIENT_ID = '3HY0EIIC1JF4PNO4VU3SVLCKV53R5M4JIKP3HPGWM0XIVTPQ' # your Foursquare ID
CLIENT_SECRET = 'BUAYUWBOROSURIXFGBQHVMPRVDSJCNMBPZEAFVVS0Z5VCNAP' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)



#Let's explore the first neighborhood in our dataframe.
#Get the neighborhood's name
manhattan_data.loc[0, 'Neighborhood']

#Get the neighborhood's latitude and longitude values
neighborhood_latitude = manhattan_data.loc[0, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = manhattan_data.loc[0, 'Longitude'] # neighborhood longitude value
neighborhood_name = manhattan_data.loc[0, 'Neighborhood'] # neighborhood name
print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))


#Now, let's get the top 100 venues that are in Marble Hill within a radius of 500 meters
#First, let's create the GET request URL. Name your URL url.
radius = 500
LIMIT = 100
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, neighborhood_latitude, neighborhood_longitude, VERSION, radius, LIMIT)
url
# Out:
# Your credentails:
# CLIENT_ID: 3HY0EIIC1JF4PNO4VU3SVLCKV53R5M4JIKP3HPGWM0XIVTPQ
# CLIENT_SECRET:BUAYUWBOROSURIXFGBQHVMPRVDSJCNMBPZEAFVVS0Z5VCNAP
# Latitude and longitude values of Marble Hill are 40.87655077879964, -73.91065965862981.
# 'https://api.foursquare.com/v2/venues/search?client_id=3HY0EIIC1JF4PNO4VU3SVLCKV53R5M4JIKP3HPGWM0XIVTPQ&client_secret=BUAYUWBOROSURIXFGBQHVMPRVDSJCNMBPZEAFVVS0Z5VCNAP&ll=40.87655077879964,-73.91065965862981&v=20180605&radius=500&limit=100'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5c26eb514c1f677d4498dece'},
#  'response': {'confident': False,
#   'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/neighborhood_',
#        'suffix': '.png'},
#       'id': '4f2a25ac4b909258e854f55f',
#       'name': 'Neighborhood',
#       'pluralName': 'Neighborhoods',
#       'primary': True,
#       'shortName': 'Neighborhood'}],
#     'hasPerk': False,
#     'id': '4eaa78cc4fc6d0cb8bbabcda',
#     'location': {'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 61,
#      'formattedAddress': ['New York, NY 10463', 'United States'],
#      'lat': 40.876111,
#      'lng': -73.911111,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': 'Marble Hill',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'primary': True,
#       'shortName': 'Church'}],
#     'hasPerk': False,
#     'id': '4e6cae6ab0fba3f50e66eb7a',
#     'location': {'address': '3021 Kingsbridge Ave',
#      'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'crossStreet': 'Near 230th Street',
#      'distance': 84,
#      'formattedAddress': ['3021 Kingsbridge Ave (Near 230th Street)',
#       'Bronx, NY 10463',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.876173669809965,
#        'lng': -73.9097948544221}],
#      'lat': 40.876173669809965,
#      'lng': -73.9097948544221,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': 'St. Johns Roman Catholic Church',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'primary': True,
#       'shortName': 'Pizza'}],
#     'delivery': {'id': '72548',
#      'provider': {'icon': {'name': '/delivery_provider_seamless_20180129.png',
#        'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50]},
#       'name': 'seamless'},
#      'url': 'https://www.seamless.com/menu/arturos-pizza-5189-broadway-ave-new-york/72548?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=72548'},
#     'hasPerk': False,
#     'id': '4b4429abf964a52037f225e3',
#     'location': {'address': '5198 Broadway',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'crossStreet': 'at 225th St.',
#      'distance': 240,
#      'formattedAddress': ['5198 Broadway (at 225th St.)',
#       'New York, NY 10463',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.87441177110231,
#        'lng': -73.91027100981574}],
#      'lat': 40.87441177110231,
#      'lng': -73.91027100981574,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': "Arturo's",
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'primary': True,
#       'shortName': 'Supermarket'}],
#     'hasPerk': False,
#     'id': '4c28a25d3492a593929ab728',
#     'location': {'address': '4918 Broadway',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 182,
#      'formattedAddress': ['4918 Broadway',
#       'New York, NY 10034',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.87621750357271,
#        'lng': -73.90854098747018}],
#      'lat': 40.87621750357271,
#      'lng': -73.90854098747018,
#      'postalCode': '10034',
#      'state': 'NY'},
#     'name': 'CTown Supermarkets',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'primary': True,
#       'shortName': 'Hospital'}],
#     'hasPerk': False,
#     'id': '56781a0c498ec86117515307',
#     'location': {'address': '5141 Broadway',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'crossStreet': '220th',
#      'distance': 403,
#      'formattedAddress': ['5141 Broadway (220th)',
#       'New York, NY 10034',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.87335797725655,
#        'lng': -73.9129406925142}],
#      'lat': 40.87335797725655,
#      'lng': -73.9129406925142,
#      'postalCode': '10034',
#      'state': 'NY'},
#     'name': 'The Spine Hospital',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/carwash_',
#        'suffix': '.png'},
#       'id': '4f04ae1f2fb6e1c99f3db0ba',
#       'name': 'Car Wash',
#       'pluralName': 'Car Washes',
#       'primary': True,
#       'shortName': 'Car Washes'}],
#     'hasPerk': False,
#     'id': '4bd07c8241b9ef3b9626fae5',
#     'location': {'address': '5134 Broadway',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'crossStreet': 'W 220th St',
#      'distance': 511,
#      'formattedAddress': ['5134 Broadway (W 220th St)',
#       'New York, NY 10034',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.87214174971612,
#        'lng': -73.91238991298299}],
#      'lat': 40.87214174971612,
#      'lng': -73.91238991298299,
#      'postalCode': '10034',
#      'state': 'NY'},
#     'name': 'Broadway Bridge Wash & Lube',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/housingdevelopment_',
#        'suffix': '.png'},
#       'id': '4f2a210c4b9023bd5841ed28',
#       'name': 'Housing Development',
#       'pluralName': 'Housing Developments',
#       'primary': True,
#       'shortName': 'Housing Development'}],
#     'hasPerk': False,
#     'id': '4c499026fbafc92834fd12db',
#     'location': {'address': '5365 Broadway',
#      'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'crossStreet': 'at W 230th St.',
#      'distance': 228,
#      'formattedAddress': ['5365 Broadway (at W 230th St.)',
#       'Bronx, NY 10463',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.87713528267983,
#        'lng': -73.90806096859365}],
#      'lat': 40.87713528267983,
#      'lng': -73.90806096859365,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': 'NYCHA - Marble Hill Community Center',
#     'referralId': 'v-1546054481'},
#    {'categories': [],
#     'hasPerk': False,
#     'id': '4c2a4563c758e21e6f623a3f',
#     'location': {'address': '95 West 228th Street',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 66,
#      'formattedAddress': ['95 West 228th Street',
#       'New York, NY 10463',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.876674,
#        'lng': -73.909883}],
#      'lat': 40.876674,
#      'lng': -73.909883,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': 'Deli Grocery Store',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/housingdevelopment_',
#        'suffix': '.png'},
#       'id': '4f2a210c4b9023bd5841ed28',
#       'name': 'Housing Development',
#       'pluralName': 'Housing Developments',
#       'primary': True,
#       'shortName': 'Housing Development'}],
#     'hasPerk': False,
#     'id': '4c28a1d1ce3fc9289d686d88',
#     'location': {'address': '108 W 227th St',
#      'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'crossStreet': 'Marble Hill Avenue',
#      'distance': 103,
#      'formattedAddress': ['108 W 227th St (Marble Hill Avenue)',
#       'Bronx, NY 10463',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.876604529689956,
#        'lng': -73.90942990932098}],
#      'lat': 40.876604529689956,
#      'lng': -73.90942990932098,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': '108 Marblehill',
#     'referralId': 'v-1546054481'},
#    {'categories': [],
#     'hasPerk': False,
#     'id': '4bac30b4f964a5201dea3ae3',
#     'location': {'address': '225 w',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 172,
#      'formattedAddress': ['225 w', 'New York, NY', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.87513267993927,
#        'lng': -73.90984654426575}],
#      'lat': 40.87513267993927,
#      'lng': -73.90984654426575,
#      'state': 'NY'},
#     'name': "Allan's Hut",
#     'referralId': 'v-1546054481'},
#    {'categories': [],
#     'hasPerk': False,
#     'id': '4de3eec02271bfb844bea8d8',
#     'location': {'address': 'Adrian and 227th St.',
#      'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'distance': 62,
#      'formattedAddress': ['Adrian and 227th St.',
#       'Bronx, NY 10463',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.877108914285714,
#        'lng': -73.91057287}],
#      'lat': 40.877108914285714,
#      'lng': -73.91057287,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': "Wampy's Sky Loft",
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d13d941735',
#       'name': 'High School',
#       'pluralName': 'High Schools',
#       'primary': True,
#       'shortName': 'High School'}],
#     'hasPerk': False,
#     'id': '4b41fb4af964a520fcca25e3',
#     'location': {'address': '99 Terrace View Ave',
#      'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'distance': 199,
#      'formattedAddress': ['99 Terrace View Ave',
#       'Bronx, NY 10463',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.876943548473825,
#        'lng': -73.91297551876026}],
#      'lat': 40.876943548473825,
#      'lng': -73.91297551876026,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': 'John F. Kennedy High School',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'id': '52f2ab2ebcbc57f1066b8b47',
#       'name': 'Boxing Gym',
#       'pluralName': 'Boxing Gyms',
#       'primary': True,
#       'shortName': 'Boxing Gym'}],
#     'hasPerk': False,
#     'id': '4fc6271c6d86c6e73862be35',
#     'location': {'address': '5500 Broadway',
#      'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'distance': 217,
#      'formattedAddress': ['5500 Broadway', 'Bronx, NY 10463', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.8756708933038,
#        'lng': -73.90835523605347}],
#      'lat': 40.8756708933038,
#      'lng': -73.90835523605347,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': 'Bronx Boxing',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'primary': True,
#       'shortName': 'Residential'}],
#     'hasPerk': False,
#     'id': '51005695e4b07f825b5cdd1f',
#     'location': {'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'distance': 121,
#      'formattedAddress': ['Bronx, NY 10463', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.87590903761338,
#        'lng': -73.91182152922055}],
#      'lat': 40.87590903761338,
#      'lng': -73.91182152922055,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': '10 Adrian Ave',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sceniclookout_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d165941735',
#       'name': 'Scenic Lookout',
#       'pluralName': 'Scenic Lookouts',
#       'primary': True,
#       'shortName': 'Scenic Lookout'}],
#     'hasPerk': False,
#     'id': '4e6259bcae60e9edf5b4f396',
#     'location': {'address': 'W 228th St. at Broadway',
#      'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'distance': 202,
#      'formattedAddress': ['W 228th St. at Broadway',
#       'Bronx, NY 10463',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.87594862476864,
#        'lng': -73.90839396773141}],
#      'lat': 40.87594862476864,
#      'lng': -73.90839396773141,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': 'The Secret Stairs',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/eventspace_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d171941735',
#       'name': 'Event Space',
#       'pluralName': 'Event Spaces',
#       'primary': True,
#       'shortName': 'Event Space'}],
#     'hasPerk': False,
#     'id': '4bdcbf33afe8c9b6e5d85085',
#     'location': {'address': 'W 225 st',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'crossStreet': 'Marble Hill Ave',
#      'distance': 203,
#      'formattedAddress': ['W 225 st (Marble Hill Ave)',
#       'New York, NY 10463',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.874776,
#        'lng': -73.911239}],
#      'lat': 40.874776,
#      'lng': -73.911239,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': 'The Wall on W225 St',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d146941735',
#       'name': 'Deli / Bodega',
#       'pluralName': 'Delis / Bodegas',
#       'primary': True,
#       'shortName': 'Deli / Bodega'}],
#     'hasPerk': False,
#     'id': '4c8ec5b14e95236a56e27eca',
#     'location': {'address': '151 W 228th St',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 136,
#      'formattedAddress': ['151 W 228th St',
#       'New York, NY 10463',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.87715778333333,
#        'lng': -73.9092566}],
#      'lat': 40.87715778333333,
#      'lng': -73.9092566,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': '151 Grocery/Deli',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/beauty_cosmetic_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10c951735',
#       'name': 'Cosmetics Shop',
#       'pluralName': 'Cosmetics Shops',
#       'primary': True,
#       'shortName': 'Cosmetics'}],
#     'hasPerk': False,
#     'id': '4c9e6e2203133704dcf668d5',
#     'location': {'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'distance': 178,
#      'formattedAddress': ['Bronx, NY 10463', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.87623429042713,
#        'lng': -73.91274012841446}],
#      'lat': 40.87623429042713,
#      'lng': -73.91274012841446,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': 'Terrace View Salon',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d110951735',
#       'name': 'Salon / Barbershop',
#       'pluralName': 'Salons / Barbershops',
#       'primary': True,
#       'shortName': 'Salon / Barbershop'}],
#     'hasPerk': False,
#     'id': '512901b5e4b0ce6661fefdc1',
#     'location': {'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'distance': 148,
#      'formattedAddress': ['Bronx, NY 10463', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.87738929799393,
#        'lng': -73.90928264388714}],
#      'lat': 40.87738929799393,
#      'lng': -73.90928264388714,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': 'Marble Hill Unisex',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1fe931735',
#       'name': 'Bus Station',
#       'pluralName': 'Bus Stations',
#       'primary': True,
#       'shortName': 'Bus Station'}],
#     'hasPerk': False,
#     'id': '4d28b04df7a9224b286df79f',
#     'location': {'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'distance': 223,
#      'formattedAddress': ['Bronx, NY', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.876026,
#        'lng': -73.908092}],
#      'lat': 40.876026,
#      'lng': -73.908092,
#      'state': 'NY'},
#     'name': 'MTA BX7, BX9, BX20 (Broadway/West 228 St)',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d146941735',
#       'name': 'Deli / Bodega',
#       'pluralName': 'Delis / Bodegas',
#       'primary': True,
#       'shortName': 'Deli / Bodega'}],
#     'hasPerk': False,
#     'id': '4ed7956b8b81b2bf28adc714',
#     'location': {'address': '135 Terrace View Ave.',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 175,
#      'formattedAddress': ['135 Terrace View Ave.',
#       'New York, NY 10034',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.87647647652852,
#        'lng': -73.91274586964578}],
#      'lat': 40.87647647652852,
#      'lng': -73.91274586964578,
#      'postalCode': '10034',
#      'state': 'NY'},
#     'name': 'Terrace View Delicatessen',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d146941735',
#       'name': 'Deli / Bodega',
#       'pluralName': 'Delis / Bodegas',
#       'primary': True,
#       'shortName': 'Deli / Bodega'}],
#     'hasPerk': False,
#     'id': '4f00ce265c5c51dd2f44809c',
#     'location': {'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'distance': 178,
#      'formattedAddress': ['Bronx, NY 10463', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.875896764511964,
#        'lng': -73.91259085634037}],
#      'lat': 40.875896764511964,
#      'lng': -73.91259085634037,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': 'Hernandez Grocery',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/laundry_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1fc941735',
#       'name': 'Laundry Service',
#       'pluralName': 'Laundry Services',
#       'primary': True,
#       'shortName': 'Laundry'}],
#     'hasPerk': False,
#     'id': '4baf5709f964a520fdf83be3',
#     'location': {'cc': 'US',
#      'country': 'United States',
#      'distance': 145,
#      'formattedAddress': ['New York', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.877786285754794,
#        'lng': -73.9100874563653}],
#      'lat': 40.877786285754794,
#      'lng': -73.9100874563653,
#      'state': 'New York'},
#     'name': 'So Fresh So Clean Laundromat',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d13d941735',
#       'name': 'High School',
#       'pluralName': 'High Schools',
#       'primary': True,
#       'shortName': 'High School'}],
#     'hasPerk': False,
#     'id': '4ce153f33644a093bd845c9f',
#     'location': {'address': '99 Terrace View Ave',
#      'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'distance': 159,
#      'formattedAddress': ['99 Terrace View Ave',
#       'Bronx, NY 10463',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.87595246759077,
#        'lng': -73.91238417174114}],
#      'lat': 40.87595246759077,
#      'lng': -73.91238417174114,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': 'Bronx Theatre High School',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/flowershop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d11b951735',
#       'name': 'Flower Shop',
#       'pluralName': 'Flower Shops',
#       'primary': True,
#       'shortName': 'Flower Shop'}],
#     'hasPerk': False,
#     'id': '53a0b85e498eeec38e50ee07',
#     'location': {'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 214,
#      'formattedAddress': ['New York, NY 10463', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.87487497272017,
#        'lng': -73.90939870305984}],
#      'lat': 40.87487497272017,
#      'lng': -73.90939870305984,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': 'flowers by Zenda',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'primary': True,
#       'shortName': 'Office'}],
#     'hasPerk': False,
#     'id': '4d90d828ca75b60cb01931a9',
#     'location': {'address': '90 W 225th St',
#      'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'distance': 210,
#      'formattedAddress': ['90 W 225th St', 'Bronx, NY 10463', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.8747422,
#        'lng': -73.90992465}],
#      'lat': 40.8747422,
#      'lng': -73.90992465,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': 'River Plaza Management Office',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d110951735',
#       'name': 'Salon / Barbershop',
#       'pluralName': 'Salons / Barbershops',
#       'primary': True,
#       'shortName': 'Salon / Barbershop'}],
#     'hasPerk': False,
#     'id': '4e0f7d4c8877936cb40fca53',
#     'location': {'address': '5223 Broadway',
#      'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'distance': 208,
#      'formattedAddress': ['5223 Broadway', 'Bronx, NY 10463', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.87501167759571,
#        'lng': -73.9092436870901}],
#      'lat': 40.87501167759571,
#      'lng': -73.9092436870901,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': 'Explosion 2000 Barber shop',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e5931735',
#       'name': 'Music Venue',
#       'pluralName': 'Music Venues',
#       'primary': True,
#       'shortName': 'Music Venue'}],
#     'hasPerk': False,
#     'id': '4e583503fa76435f0bdac572',
#     'location': {'address': '52 Marble Hill ave',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 129,
#      'formattedAddress': ['52 Marble Hill ave',
#       'New York, NY',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.87570701775556,
#        'lng': -73.90960539082762}],
#      'lat': 40.87570701775556,
#      'lng': -73.90960539082762,
#      'state': 'NY'},
#     'name': 'Villa Lobos',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'id': '52f2ab2ebcbc57f1066b8b27',
#       'name': 'Mattress Store',
#       'pluralName': 'Mattress Stores',
#       'primary': True,
#       'shortName': 'Mattress Store'}],
#     'hasPerk': False,
#     'id': '598c83fe345cbe1f60fd3644',
#     'location': {'address': '5199 Broadway, Bronx',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 216,
#      'formattedAddress': ['5199 Broadway, Bronx',
#       'New York, NY 10463',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.874695,
#        'lng': -73.90991}],
#      'lat': 40.874695,
#      'lng': -73.90991,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': 'Matress Firm',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'primary': True,
#       'shortName': 'Church'}],
#     'hasPerk': False,
#     'id': '4e5124af8877402b06daf6f1',
#     'location': {'address': '146 W 228th St',
#      'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'crossStreet': 'Broadway and Marble Hill Avenue',
#      'distance': 138,
#      'formattedAddress': ['146 W 228th St (Broadway and Marble Hill Avenue)',
#       'Bronx, NY 10463',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.87696732699542,
#        'lng': -73.90910625457764}],
#      'lat': 40.87696732699542,
#      'lng': -73.90910625457764,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': 'St. Stephens UMC',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'primary': True,
#       'shortName': 'Sandwiches'}],
#     'hasPerk': False,
#     'id': '4cfa9cabd8468cfa960eef6b',
#     'location': {'address': '5223 Broadway',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 203,
#      'formattedAddress': ['5223 Broadway',
#       'New York, NY 10034',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.8749112481242,
#        'lng': -73.90959964950369}],
#      'lat': 40.8749112481242,
#      'lng': -73.90959964950369,
#      'postalCode': '10034',
#      'state': 'NY'},
#     'name': 'Habib Deli',
#     'referralId': 'v-1546054481'},
#    {'categories': [],
#     'hasPerk': False,
#     'id': '5171c1ad498efc18ac2c8df1',
#     'location': {'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 207,
#      'formattedAddress': ['New York, NY', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.87475905464431,
#        'lng': -73.91000154176955}],
#      'lat': 40.87475905464431,
#      'lng': -73.91000154176955,
#      'state': 'NY'},
#     'name': 'Explosion Barber Shop',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/laundry_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1fc941735',
#       'name': 'Laundry Service',
#       'pluralName': 'Laundry Services',
#       'primary': True,
#       'shortName': 'Laundry'}],
#     'hasPerk': False,
#     'id': '4ed42501e5faa5ec072672f0',
#     'location': {'address': '121 W 227th St, Bronx, NY 10463',
#      'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'distance': 79,
#      'formattedAddress': ['121 W 227th St, Bronx, NY 10463',
#       'Bronx, NY 10463',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.87709866207294,
#        'lng': -73.91005039215088}],
#      'lat': 40.87709866207294,
#      'lng': -73.91005039215088,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': 'The Bird Bath',
#     'referralId': 'v-1546054481'},
#    {'categories': [],
#     'hasPerk': False,
#     'id': '4cc39d49306e224bec5c986c',
#     'location': {'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'distance': 129,
#      'formattedAddress': ['Bronx, NY', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.87620093,
#        'lng': -73.91213155}],
#      'lat': 40.87620093,
#      'lng': -73.91213155,
#      'state': 'NY'},
#     'name': 'The Lime',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'primary': True,
#       'shortName': 'Pharmacy'}],
#     'hasPerk': False,
#     'id': '572ba48f498e3a5e175667e3',
#     'location': {'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 207,
#      'formattedAddress': ['New York, NY', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.87505,
#        'lng': -73.909195}],
#      'lat': 40.87505,
#      'lng': -73.909195,
#      'state': 'NY'},
#     'name': 'marble  hill pharmacy',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d177941735',
#       'name': "Doctor's Office",
#       'pluralName': "Doctor's Offices",
#       'primary': True,
#       'shortName': "Doctor's Office"}],
#     'hasPerk': False,
#     'id': '5a4df2aec4df1d0cac07c3c0',
#     'location': {'address': '5221 Broadway',
#      'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'distance': 167,
#      'formattedAddress': ['5221 Broadway', 'Bronx, NY 10463', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.87531394629997,
#        'lng': -73.90953540802002}],
#      'lat': 40.87531394629997,
#      'lng': -73.90953540802002,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': 'USA Vein Clinics',
#     'referralId': 'v-1546054481'},
#    {'categories': [],
#     'hasPerk': False,
#     'id': '4c01904e3ab80f479b5b90ff',
#     'location': {'address': '10 Adrian Ave',
#      'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'distance': 152,
#      'formattedAddress': ['10 Adrian Ave', 'Bronx, NY 10463', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.876047,
#        'lng': -73.912347}],
#      'lat': 40.876047,
#      'lng': -73.912347,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': 'Meaghan',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_wineshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d119951735',
#       'name': 'Wine Shop',
#       'pluralName': 'Wine Shops',
#       'primary': True,
#       'shortName': 'Wine Shop'}],
#     'hasPerk': False,
#     'id': '4c82acc8d34ca1432fa12e80',
#     'location': {'address': '5203 Broadway',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 234,
#      'formattedAddress': ['5203 Broadway',
#       'New York, NY 10034',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.87453507472922,
#        'lng': -73.90983199353421}],
#      'lat': 40.87453507472922,
#      'lng': -73.90983199353421,
#      'postalCode': '10034',
#      'state': 'NY'},
#     'name': 'Wine & Liquors',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'primary': True,
#       'shortName': 'Asian'}],
#     'hasPerk': False,
#     'id': '4c703518b5a5236a2d934f52',
#     'location': {'address': '5400 Broadway',
#      'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'distance': 173,
#      'formattedAddress': ['5400 Broadway', 'Bronx, NY 10463', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.87608431180527,
#        'lng': -73.90869825954931}],
#      'lat': 40.87608431180527,
#      'lng': -73.90869825954931,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': 'Kam Wah Kitchen',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/trainstation_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d129951735',
#       'name': 'Train Station',
#       'pluralName': 'Train Stations',
#       'primary': True,
#       'shortName': 'Train Station'}],
#     'hasPerk': False,
#     'id': '4b5e0e1ff964a520357b29e3',
#     'location': {'address': '1 West 225th St',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 237,
#      'formattedAddress': ['1 West 225th St',
#       'New York, NY 10463',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.87469809860372,
#        'lng': -73.91205168105456}],
#      'lat': 40.87469809860372,
#      'lng': -73.91205168105456,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': 'Metro North - Marble Hill Train Station',
#     'referralId': 'v-1546054481'},
#    {'categories': [],
#     'hasPerk': False,
#     'id': '4dee7779d22deb0316f7c075',
#     'location': {'address': '22 Marble Hill Ave',
#      'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'distance': 214,
#      'formattedAddress': ['22 Marble Hill Ave',
#       'Bronx, NY 10463',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.87836,
#        'lng': -73.91153}],
#      'lat': 40.87836,
#      'lng': -73.91153,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': 'Special Citizens Futures Unlimited, Inc.',
#     'referralId': 'v-1546054481'},
#    {'categories': [],
#     'hasPerk': False,
#     'id': '4c28e85efe6e2d7f0300543c',
#     'location': {'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'distance': 74,
#      'formattedAddress': ['Bronx, NY 10463', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.87669,
#        'lng': -73.909791}],
#      'lat': 40.87669,
#      'lng': -73.909791,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': 'Star Grocery',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'primary': True,
#       'shortName': 'Fast Food'}],
#     'hasPerk': False,
#     'id': '5600a79f498e50d63bec7cdd',
#     'location': {'address': '5225 Broadway',
#      'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'distance': 213,
#      'formattedAddress': ['5225 Broadway', 'Bronx, NY 10463', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.874986,
#        'lng': -73.909184}],
#      'lat': 40.874986,
#      'lng': -73.909184,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': 'Kennedy Chicken & Pizza',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d110951735',
#       'name': 'Salon / Barbershop',
#       'pluralName': 'Salons / Barbershops',
#       'primary': True,
#       'shortName': 'Salon / Barbershop'}],
#     'hasPerk': False,
#     'id': '5002dc8ee4b06d501876839b',
#     'location': {'address': '5215 Broadway',
#      'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'distance': 210,
#      'formattedAddress': ['5215 Broadway', 'Bronx, NY 10463', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.87491348861792,
#        'lng': -73.90941018571937}],
#      'lat': 40.87491348861792,
#      'lng': -73.90941018571937,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': 'ED Beauty Salon',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/nailsalon_',
#        'suffix': '.png'},
#       'id': '4f04aa0c2fb6e1c99f3db0b8',
#       'name': 'Nail Salon',
#       'pluralName': 'Nail Salons',
#       'primary': True,
#       'shortName': 'Nail Salon'}],
#     'hasPerk': False,
#     'id': '4e5e7a45b61cebc23b70e379',
#     'location': {'address': '110 W 228th St',
#      'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'crossStreet': 'Broadway',
#      'distance': 208,
#      'formattedAddress': ['110 W 228th St (Broadway)',
#       'Bronx, NY 10463',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.87601874245607,
#        'lng': -73.9082833482036}],
#      'lat': 40.87601874245607,
#      'lng': -73.9082833482036,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': 'Le Chalan Nail Salon',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/caribbean_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d144941735',
#       'name': 'Caribbean Restaurant',
#       'pluralName': 'Caribbean Restaurants',
#       'primary': True,
#       'shortName': 'Caribbean'}],
#     'hasPerk': False,
#     'id': '53063cd5498ec871d9fa0216',
#     'location': {'address': '111A W 225th Street',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 129,
#      'formattedAddress': ['111A W 225th Street',
#       'New York, NY 10463',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.875399064940325,
#        'lng': -73.91083403025367}],
#      'lat': 40.875399064940325,
#      'lng': -73.91083403025367,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': 'the Nook',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/nailsalon_',
#        'suffix': '.png'},
#       'id': '4f04aa0c2fb6e1c99f3db0b8',
#       'name': 'Nail Salon',
#       'pluralName': 'Nail Salons',
#       'primary': True,
#       'shortName': 'Nail Salon'}],
#     'hasPerk': False,
#     'id': '4ca113c78afca09361391816',
#     'location': {'address': '110 W 228th St',
#      'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'crossStreet': 'Broadway',
#      'distance': 211,
#      'formattedAddress': ['110 W 228th St (Broadway)',
#       'Bronx, NY 10463',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.876133976062945,
#        'lng': -73.90820450277454}],
#      'lat': 40.876133976062945,
#      'lng': -73.90820450277454,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': "Daisy's Nail",
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d146941735',
#       'name': 'Deli / Bodega',
#       'pluralName': 'Delis / Bodegas',
#       'primary': True,
#       'shortName': 'Deli / Bodega'}],
#     'hasPerk': False,
#     'id': '4cc449c901fb236aa2dfaaba',
#     'location': {'address': '245 W 230th St',
#      'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'distance': 140,
#      'formattedAddress': ['245 W 230th St',
#       'Bronx, NY 10463',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.87739543593099,
#        'lng': -73.9094216683782}],
#      'lat': 40.87739543593099,
#      'lng': -73.9094216683782,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': 'Kingsbridge Grocery/Deli',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/drycleaner_',
#        'suffix': '.png'},
#       'id': '52f2ab2ebcbc57f1066b8b1d',
#       'name': 'Dry Cleaner',
#       'pluralName': 'Dry Cleaners',
#       'primary': True,
#       'shortName': 'Dry Cleaner'}],
#     'hasPerk': False,
#     'id': '5b15c47d6eda02002c4596ef',
#     'location': {'address': '108 W228 St',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 181,
#      'formattedAddress': ['108 W228 St',
#       'New York, NY 10463',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.876088,
#        'lng': -73.908595}],
#      'lat': 40.876088,
#      'lng': -73.908595,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': 'Jasmin Cleaners',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d13b941735',
#       'name': 'School',
#       'pluralName': 'Schools',
#       'primary': True,
#       'shortName': 'School'}],
#     'hasPerk': False,
#     'id': '4de6ee22152016a6c0757bf4',
#     'location': {'address': '99 Terrace View Ave',
#      'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'distance': 200,
#      'formattedAddress': ['99 Terrace View Ave',
#       'Bronx, NY 10463',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.877391667555415,
#        'lng': -73.91276883456942}],
#      'lat': 40.877391667555415,
#      'lng': -73.91276883456942,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': 'The New Visions Charter High School for the Humanities',
#     'referralId': 'v-1546054481'},
#    {'categories': [],
#     'hasPerk': False,
#     'id': '4ce43fbe4039b60c7d0ec006',
#     'location': {'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'distance': 215,
#      'formattedAddress': ['Bronx, NY 10463', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.87471362199872,
#        'lng': -73.91146659851074}],
#      'lat': 40.87471362199872,
#      'lng': -73.91146659851074,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': 'Winston Churchill Gym',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d146941735',
#       'name': 'Deli / Bodega',
#       'pluralName': 'Delis / Bodegas',
#       'primary': True,
#       'shortName': 'Deli / Bodega'}],
#     'hasPerk': False,
#     'id': '4cd890f351fc8cfa4159ea5d',
#     'location': {'address': '5189 Broadway',
#      'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'distance': 194,
#      'formattedAddress': ['5189 Broadway', 'Bronx, NY 10463', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.874803316379925,
#        'lng': -73.91074216963008}],
#      'lat': 40.874803316379925,
#      'lng': -73.91074216963008,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': "Garden Of Eatin'",
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/office_coworkingspace_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d174941735',
#       'name': 'Coworking Space',
#       'pluralName': 'Coworking Spaces',
#       'primary': True,
#       'shortName': 'Coworking Space'}],
#     'hasPerk': False,
#     'id': '4e1f1ec4b0fbe764a4ab49e5',
#     'location': {'address': '129 Terrace View Ave',
#      'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'distance': 210,
#      'formattedAddress': ['129 Terrace View Ave',
#       'Bronx, NY 10463',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.876311,
#        'lng': -73.913145}],
#      'lat': 40.876311,
#      'lng': -73.913145,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': 'Bettter Taxes',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/conventioncenter_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1ff931735',
#       'name': 'Convention Center',
#       'pluralName': 'Convention Centers',
#       'primary': True,
#       'shortName': 'Convention Center'}],
#     'hasPerk': False,
#     'id': '4eab64ee93ad72a2dad9425f',
#     'location': {'address': '53 Adrian Ave, New York, NY 10463',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 216,
#      'formattedAddress': ['53 Adrian Ave, New York, NY 10463',
#       'New York, NY 10463',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.87838446666667,
#        'lng': -73.9098032}],
#      'lat': 40.87838446666667,
#      'lng': -73.9098032,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': 'Andrew J. Leddy Memorial Hall',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'primary': True,
#       'shortName': 'Residential'}],
#     'hasPerk': False,
#     'id': '4f8afbf2e4b03a0f26d68569',
#     'location': {'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'distance': 198,
#      'formattedAddress': ['Bronx, NY 10463', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.875085,
#        'lng': -73.912001}],
#      'lat': 40.875085,
#      'lng': -73.912001,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': '135 W 225th',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'primary': True,
#       'shortName': 'Food'}],
#     'hasPerk': False,
#     'id': '4e01d7a41838cb6a1acf1be5',
#     'location': {'address': '5219 Broadway',
#      'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'crossStreet': '225th St',
#      'distance': 205,
#      'formattedAddress': ['5219 Broadway (225th St)',
#       'Bronx, NY 10463',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.87497533168495,
#        'lng': -73.9093814790693}],
#      'lat': 40.87497533168495,
#      'lng': -73.9093814790693,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': 'Franco #2 Bakery',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/laundry_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1fc941735',
#       'name': 'Laundry Service',
#       'pluralName': 'Laundry Services',
#       'primary': True,
#       'shortName': 'Laundry'}],
#     'hasPerk': False,
#     'id': '4dc96c9988774c7090b6bc2c',
#     'location': {'address': '215 W 230th St',
#      'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'distance': 174,
#      'formattedAddress': ['215 W 230th St',
#       'Bronx, NY 10463',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.87631606834333,
#        'lng': -73.90860472768848}],
#      'lat': 40.87631606834333,
#      'lng': -73.90860472768848,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': 'W 230 Laundry Services',
#     'referralId': 'v-1546054481'},
#    {'categories': [],
#     'hasPerk': False,
#     'id': '4bb50e87941ad13a8bad1de3',
#     'location': {'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'distance': 183,
#      'formattedAddress': ['Bronx, NY 10463', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.874907,
#        'lng': -73.910706}],
#      'lat': 40.874907,
#      'lng': -73.910706,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': "carmine's",
# ...
#       'Bronx, NY 10463',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.877849,
#        'lng': -73.910064}],
#      'lat': 40.877849,
#      'lng': -73.910064,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': 'Security Guards - National Security Service, LLC',
#     'referralId': 'v-1546054481',
#     'venuePage': {'id': '100922038'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'primary': True,
#       'shortName': 'Residential'}],
#     'hasPerk': False,
#     'id': '4da219d97aee5481d483cffe',
#     'location': {'address': '750 Kappock St',
#      'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'distance': 192,
#      'formattedAddress': ['750 Kappock St',
#       'Bronx, NY 10463',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.87595252649658,
#        'lng': -73.90850879488833}],
#      'lat': 40.87595252649658,
#      'lng': -73.90850879488833,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': "Grandma Mindy's With Horace",
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_dentist_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d178941735',
#       'name': "Dentist's Office",
#       'pluralName': "Dentist's Offices",
#       'primary': True,
#       'shortName': "Dentist's Office"}],
#     'hasPerk': False,
#     'id': '4e682cba6365d0e7120d32c7',
#     'location': {'address': '112 W 228th St',
#      'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'distance': 211,
#      'formattedAddress': ['112 W 228th St',
#       'Bronx, NY 10463',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.875783452897316,
#        'lng': -73.90836596488953}],
#      'lat': 40.875783452897316,
#      'lng': -73.90836596488953,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': 'Marble Hill Dental Office',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1ff941735',
#       'name': 'Miscellaneous Shop',
#       'pluralName': 'Miscellaneous Shops',
#       'primary': True,
#       'shortName': 'Shop'}],
#     'hasPerk': False,
#     'id': '52d8232111d2fbc0a7e9c9a1',
#     'location': {'address': '5223 Broadway Fl 2',
#      'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'crossStreet': '225 street',
#      'distance': 194,
#      'formattedAddress': ['5223 Broadway Fl 2 (225 street)',
#       'Bronx, NY 10463',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.875070572239366,
#        'lng': -73.90943348407745}],
#      'lat': 40.875070572239366,
#      'lng': -73.90943348407745,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': 'Healthy living club. Herbalife',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'primary': True,
#       'shortName': 'Bakery'}],
#     'hasPerk': False,
#     'id': '52bb1191498efe0df41e8a46',
#     'location': {'address': '5219 Broadway',
#      'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'distance': 242,
#      'formattedAddress': ['5219 Broadway', 'Bronx, NY 10463', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.874753,
#        'lng': -73.909024}],
#      'lat': 40.874753,
#      'lng': -73.909024,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': 'rosaria bakery',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d12b951735',
#       'name': 'Bus Line',
#       'pluralName': 'Bus Lines',
#       'primary': True,
#       'shortName': 'Bus'}],
#     'hasPerk': False,
#     'id': '4ce1b26daba88cfab9ca56d7',
#     'location': {'address': 'Broadway',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'crossStreet': '211 st',
#      'distance': 143,
#      'formattedAddress': ['Broadway (211 st)',
#       'New York, NY 10034',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.876051,
#        'lng': -73.912237}],
#      'lat': 40.876051,
#      'lng': -73.912237,
#      'postalCode': '10034',
#      'state': 'NY'},
#     'name': 'Bx 7, M100, Bx20',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d126941735',
#       'name': 'Government Building',
#       'pluralName': 'Government Buildings',
#       'primary': True,
#       'shortName': 'Government'}],
#     'hasPerk': False,
#     'id': '50180ceee4b01b274eefce3c',
#     'location': {'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'distance': 153,
#      'formattedAddress': ['Bronx, NY 10463', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.87589659630115,
#        'lng': -73.90905996429954}],
#      'lat': 40.87589659630115,
#      'lng': -73.90905996429954,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': 'New York City Marshall',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'primary': True,
#       'shortName': 'Church'}],
#     'hasPerk': False,
#     'id': '4cf2bd627e93f04d939e5469',
#     'location': {'address': '5233 Broadway',
#      'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'distance': 203,
#      'formattedAddress': ['5233 Broadway', 'Bronx, NY 10463', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.87557173343971,
#        'lng': -73.9086236219776}],
#      'lat': 40.87557173343971,
#      'lng': -73.9086236219776,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': 'Carolina Baptist Church',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d110951735',
#       'name': 'Salon / Barbershop',
#       'pluralName': 'Salons / Barbershops',
#       'primary': True,
#       'shortName': 'Salon / Barbershop'}],
#     'hasPerk': False,
#     'id': '4e6be7d0a80957ae4483d192',
#     'location': {'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'distance': 194,
#      'formattedAddress': ['Bronx, NY', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.875019,
#        'lng': -73.909547}],
#      'lat': 40.875019,
#      'lng': -73.909547,
#      'state': 'NY'},
#     'name': 'Eduard Unisex Salon',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'id': '50328a8e91d4c4b30a586d6c',
#       'name': 'Non-Profit',
#       'pluralName': 'Non-Profits',
#       'primary': True,
#       'shortName': 'Non-Profit'}],
#     'hasPerk': False,
#     'id': '50730900e4b0f322442db787',
#     'location': {'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'distance': 187,
#      'formattedAddress': ['Bronx, NY 10463', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.87497268760696,
#        'lng': -73.90988097417684}],
#      'lat': 40.87497268760696,
#      'lng': -73.90988097417684,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': 'Special Citizens',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d13d941735',
#       'name': 'High School',
#       'pluralName': 'High Schools',
#       'primary': True,
#       'shortName': 'High School'}],
#     'hasPerk': False,
#     'id': '51191d0de4b08b4eaa51b218',
#     'location': {'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'distance': 182,
#      'formattedAddress': ['Bronx, NY 10463', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.87580869650585,
#        'lng': -73.91259659757611}],
#      'lat': 40.87580869650585,
#      'lng': -73.91259659757611,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': 'ELLIS Preparatory Academy',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/votingbooth_',
#        'suffix': '.png'},
#       'id': '4cae28ecbf23941eb1190695',
#       'name': 'Voting Booth',
#       'pluralName': 'Voting Booths',
#       'primary': True,
#       'shortName': 'Voting Booth'}],
#     'hasPerk': False,
#     'id': '509932fee4b07f2d2b3dc85a',
#     'location': {'address': '150 W 225th St',
#      'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'distance': 230,
#      'formattedAddress': ['150 W 225th St',
#       'Bronx, NY 10463',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.875027647474205,
#        'lng': -73.90879586248458}],
#      'lat': 40.875027647474205,
#      'lng': -73.90879586248458,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': 'Voting at Promenade Apts',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_wineshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d119951735',
#       'name': 'Wine Shop',
#       'pluralName': 'Wine Shops',
#       'primary': True,
#       'shortName': 'Wine Shop'}],
#     'hasPerk': False,
#     'id': '4f99fbbee4b0ad40800470d0',
#     'location': {'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'distance': 186,
#      'formattedAddress': ['Bronx, NY 10463', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.874889,
#        'lng': -73.910914}],
#      'lat': 40.874889,
#      'lng': -73.910914,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': "Cinco's Sangria Boutique",
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/furniture_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1f8941735',
#       'name': 'Furniture / Home Store',
#       'pluralName': 'Furniture / Home Stores',
#       'primary': True,
#       'shortName': 'Furniture / Home'}],
#     'hasPerk': False,
#     'id': '4ff9d2f7e4b0c98dddef1e33',
#     'location': {'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'distance': 225,
#      'formattedAddress': ['Bronx, NY 10463', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.874843,
#        'lng': -73.909224}],
#      'lat': 40.874843,
#      'lng': -73.909224,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': 'Discount Furniture Warehouse',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'primary': True,
#       'shortName': 'Pharmacy'}],
#     'hasPerk': False,
#     'id': '4b88e053f964a5208a1132e3',
#     'location': {'address': '5237 Broadway',
#      'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'crossStreet': '228th Street',
#      'distance': 190,
#      'formattedAddress': ['5237 Broadway (228th Street)',
#       'Bronx, NY 10463',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.875466574434704,
#        'lng': -73.90890629016033}],
#      'lat': 40.875466574434704,
#      'lng': -73.90890629016033,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': 'Rite Aid',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'id': '52f2ab2ebcbc57f1066b8b27',
#       'name': 'Mattress Store',
#       'pluralName': 'Mattress Stores',
#       'primary': True,
#       'shortName': 'Mattress Store'}],
#     'hasPerk': False,
#     'id': '4fbd382d7beb1a3550023c6d',
#     'location': {'address': '5199 Broadway',
#      'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'distance': 209,
#      'formattedAddress': ['5199 Broadway', 'Bronx, NY 10463', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.874710960075646,
#        'lng': -73.91016057226807}],
#      'lat': 40.874710960075646,
#      'lng': -73.91016057226807,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': "Sleepy's Riverdale",
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/furniture_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1f8941735',
#       'name': 'Furniture / Home Store',
#       'pluralName': 'Furniture / Home Stores',
#       'primary': True,
#       'shortName': 'Furniture / Home'}],
#     'hasPerk': False,
#     'id': '4c0094f534ccc9283ae5e1cd',
#     'location': {'address': '605 W 207th St',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'crossStreet': 'Broadway',
#      'distance': 234,
#      'formattedAddress': ['605 W 207th St (Broadway)',
#       'New York, NY 10034',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.87488488626725,
#        'lng': -73.90896236149659}],
#      'lat': 40.87488488626725,
#      'lng': -73.90896236149659,
#      'postalCode': '10034',
#      'state': 'NY'},
#     'name': 'El Rey Furniture',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/furniture_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1f8941735',
#       'name': 'Furniture / Home Store',
#       'pluralName': 'Furniture / Home Stores',
#       'primary': True,
#       'shortName': 'Furniture / Home'}],
#     'hasPerk': False,
#     'id': '4ff9d550e4b0fb4a846fc89e',
#     'location': {'address': '5211 Broadway',
#      'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'crossStreet': 'W. 225th Street',
#      'distance': 192,
#      'formattedAddress': ['5211 Broadway (W. 225th Street)',
#       'Bronx, NY 10463',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.874944,
#        'lng': -73.909811}],
#      'lat': 40.874944,
#      'lng': -73.909811,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': 'Riverdale Furniture & Mattress Corp',
#     'referralId': 'v-1546054481'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/automotive_',
#        'suffix': '.png'},
#       'id': '4eb1c1623b7b52c0e1adc2ec',
#       'name': 'Auto Dealership',
#       'pluralName': 'Auto Dealerships',
#       'primary': True,
#       'shortName': 'Auto Dealer'}],
#     'hasPerk': False,
#     'id': '4efca337b6347e20d4b9ecbe',
#     'location': {'address': '5089 Broadway',
#      'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'distance': 200,
#      'formattedAddress': ['5089 Broadway', 'Bronx, NY 10463', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.87513,
#        'lng': -73.90919}],
#      'lat': 40.87513,
#      'lng': -73.90919,
#      'postalCode': '10463',
#      'state': 'NY'},
#     'name': 'Super Car Motors Corp.',
#     'referralId': 'v-1546054481',
#     'venuePage': {'id': '391981694'}}]}}

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
#venues = results['response']['groups'][0]['items']
venues = results['response']['venues'] 

nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
#filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
filtered_columns = ['name', 'categories', 'location.lat', 'location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head(12)
# Out:
#                                     name  \
# 0                            Marble Hill
# 1        St. Johns Roman Catholic Church
# 2                               Arturo's
# 3                     CTown Supermarkets
# 4                     The Spine Hospital
# 5            Broadway Bridge Wash & Lube
# 6   NYCHA - Marble Hill Community Center
# 7                     Deli Grocery Store
# 8                         108 Marblehill
# 9                            Allan's Hut
# 10                      Wampy's Sky Loft
# 11           John F. Kennedy High School
#
#                                            categories        lat        lng  \
# 0   [{'icon': {'suffix': '.png', 'prefix': 'https:...  40.876111 -73.911111
# 1   [{'icon': {'suffix': '.png', 'prefix': 'https:...  40.876174 -73.909795
# 2   [{'icon': {'suffix': '.png', 'prefix': 'https:...  40.874412 -73.910271
# 3   [{'icon': {'suffix': '.png', 'prefix': 'https:...  40.876218 -73.908541
# 4   [{'icon': {'suffix': '.png', 'prefix': 'https:...  40.873358 -73.912941
# 5   [{'icon': {'suffix': '.png', 'prefix': 'https:...  40.872142 -73.912390
# 6   [{'icon': {'suffix': '.png', 'prefix': 'https:...  40.877135 -73.908061
# 7                                                  []  40.876674 -73.909883
# 8   [{'icon': {'suffix': '.png', 'prefix': 'https:...  40.876605 -73.909430
# 9                                                  []  40.875133 -73.909847
# 10                                                 []  40.877109 -73.910573
# 11  [{'icon': {'suffix': '.png', 'prefix': 'https:...  40.876944 -73.912976
#
#              categories
# 0          Neighborhood
# 1                Church
# 2           Pizza Place
# 3           Supermarket
# 4              Hospital
# 5              Car Wash
# 6   Housing Development
# 7                  None
# 8   Housing Development
# 9                  None
# 10                 None
# 11          High School

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
scarborough_venues = getNearbyVenues(names=scarborough_data['Neighborhood'],
                                   latitudes=scarborough_data['Latitude'],
                                   longitudes=scarborough_data['Longitude']
                                  )
# Out:
# Rouge, Malvern
# Highland Creek, Rouge Hill, Port Union
# Guildwood, Morningside, West Hill
# Woburn
# Cedarbrae
# Scarborough Village
# East Birchmount Park, Ionview, Kennedy Park
# Clairlea, Golden Mile, Oakridge
# Cliffcrest, Cliffside, Scarborough Village West
# Birch Cliff, Cliffside West
# Dorset Park, Scarborough Town Centre, Wexford Heights
# Maryvale, Wexford
# Agincourt
# Clarks Corners, Sullivan, Tam O'Shanter
# Agincourt North, L'Amoreaux East, Milliken, Steeles East
# L'Amoreaux West, Steeles West
# Upper Rouge

# %%
scarborough_venues.head(3)
print(scarborough_venues.groupby('Neighborhood').count()[:4])
# Out:
#                                                     Neighborhood Latitude  \
# Neighborhood
# Agincourt                                                              13
# Agincourt North, L'Amoreaux East, Milliken, Ste...                      3
# Birch Cliff, Cliffside West                                             6
# Cedarbrae                                                               2
#
#                                                     Neighborhood Longitude  \
# Neighborhood
# Agincourt                                                               13
# Agincourt North, L'Amoreaux East, Milliken, Ste...                       3
# Birch Cliff, Cliffside West                                              6
# Cedarbrae                                                                2
#
#                                                     Venue  Venue Latitude  \
# Neighborhood
# Agincourt                                              13              13
# Agincourt North, L'Amoreaux East, Milliken, Ste...      3               3
# Birch Cliff, Cliffside West                             6               6
# Cedarbrae                                               2               2
#
#                                                     Venue Longitude  \
# Neighborhood
# Agincourt                                                        13
# Agincourt North, L'Amoreaux East, Milliken, Ste...                3
# Birch Cliff, Cliffside West                                       6
# Cedarbrae                                                         2
#
#                                                     Venue Category
# Neighborhood
# Agincourt                                                       13
# Agincourt North, L'Amoreaux East, Milliken, Ste...               3
# Birch Cliff, Cliffside West                                      6
# Cedarbrae                                                        2

# %%
# one hot encoding
scarb_onehot = pd.get_dummies(scarborough_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
scarb_onehot['Neighborhood'] = scarborough_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [scarb_onehot.columns[-1]] + list(scarb_onehot.columns[:-1])
scarb_onehot = scarb_onehot[fixed_columns]

scarb_grouped = scarb_onehot.groupby('Neighborhood').mean().reset_index()

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = scarb_grouped['Neighborhood']

for ind in np.arange(scarb_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(scarb_grouped.iloc[ind, :], num_top_venues)

# %%
scarb_data = scarborough_data.drop(16)
# set number of clusters
kclusters = 5

scarb_grouped_clustering = scarb_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(scarb_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([0, 3, 0, 1, 0, 0, 0, 0, 0, 0], dtype=int32)

# %%
scarb_merged = scarb_data

# add clustering labels
scarb_merged['Cluster Labels'] = kmeans.labels_

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
scarb_merged = scarb_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

# %%
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(scarb_merged['Latitude'], scarb_merged['Longitude'], scarb_merged['Neighborhood'], scarb_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
